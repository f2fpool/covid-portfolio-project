# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

plt.style.use('ggplot')

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv(r'C:\Users\WorkGroup\Downloads\movies.csv')

# %%
df = df.dropna()

# %%
#Data types for columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data type of columns
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# creating year of release
df['year_release'] = df['released'].astype(str).str.extract(pat = '([0-9]{4})').astype(int)

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
pd.set_option('display.max_rows', None)

# %%
# Drop any duplicates
df.drop_duplicates()
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000.0
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000.0
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000.0
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000.0
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000.0
#
#              gross                company  runtime
# 5445  2.847246e+09  Twentieth Century Fox    162.0
# 7445  2.797501e+09         Marvel Studios    181.0
# 3045  2.201647e+09  Twentieth Century Fox    194.0
# 6663  2.069522e+09              Lucasfilm    138.0
# 7244  2.048360e+09         Marvel Studios    149.0

# %%
# Scatter plot with budget vs gross
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross earnings')
plt.ylabel('Budget for film')
plt.show()

# %%
#Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Looking at correlation
df.corr(method='pearson')
# Out:
#                   year     score     votes    budget     gross   runtime  \
# year          1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score         0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes         0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget        0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross         0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime       0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# year_release  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#               year_release
# year              0.998726
# score             0.061923
# votes             0.203098
# budget            0.320312
# gross             0.268721
# runtime           0.075294
# year_release      1.000000

# %%
# High correlation between Budget and Gross

correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')

plt.show()

# %%
# Looking at Company
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime  year_release
# 5445  2847246203  Twentieth Century Fox    162.0          2009
# 7445  2797501328         Marvel Studios    181.0          2019
# 3045  2201647264  Twentieth Century Fox    194.0          1997
# 6663  2069521700              Lucasfilm    138.0          2015
# 7244  2048359754         Marvel Studios    149.0          2018

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df_numerized = df
#       3 for col_name in df_numerized.columns:
#       4     if(df_numerized[col_name].dtype == 'object'):
#
# NameError: name 'df' is not defined

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation matrix for numeric features')
plt.xlabel('Movie features')
plt.ylabel('Movie features')

plt.show()

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.029234
#               genre           0.010996
#               year            0.025542
#               released       -0.006152
#               score           0.014450
#               votes           0.012615
#               director        0.015246
#               writer          0.012880
#               star           -0.006882
#               country        -0.025490
#               budget          0.023392
#               gross           0.005639
#               company         0.021697
#               runtime         0.010850
#               year_release    0.025542
# rating        name           -0.029234
#               rating          1.000000
#               genre           0.147796
#               year            0.019499
#               released        0.018083
#               score           0.065983
#               votes           0.006031
#               director        0.014656
#               writer         -0.003149
#               star            0.009196
#               country         0.008230
#               budget         -0.203946
#               gross          -0.181906
#               company        -0.092357
#               runtime         0.140792
#               year_release    0.022021
# genre         name            0.010996
#               rating          0.147796
#               genre           1.000000
#               year           -0.073167
#               released        0.022142
#               score           0.035106
#               votes          -0.135990
#               director       -0.008553
#               writer          0.017578
#               star            0.003341
#               country        -0.009164
#               budget         -0.368523
#               gross          -0.244101
#               company        -0.071334
#               runtime        -0.059237
#               year_release   -0.069147
# year          name            0.025542
#               rating          0.019499
#               genre          -0.073167
#               year            1.000000
#               released       -0.001740
#               score           0.056386
#               votes           0.206021
#               director       -0.038354
#               writer         -0.025908
#               star           -0.032157
#               country        -0.066748
#               budget          0.327722
#               gross           0.274321
#               company        -0.014333
#               runtime         0.075077
#               year_release    0.998726
# released      name           -0.006152
#               rating          0.018083
#               genre           0.022142
#               year           -0.001740
#               released        1.000000
#               score           0.045874
#               votes           0.028833
#               director        0.002308
#               writer          0.008072
#               star            0.015706
#               country        -0.017228
#               budget          0.019952
#               gross           0.008501
#               company        -0.002407
#               runtime         0.008975
#               year_release   -0.005989
# score         name            0.014450
#               rating          0.065983
#               genre           0.035106
#               year            0.056386
#               released        0.045874
#               score           1.000000
#               votes           0.474256
#               director        0.005413
#               writer          0.012843
#               star            0.007296
#               country        -0.043051
#               budget          0.072001
#               gross           0.222556
#               company         0.020656
#               runtime         0.414068
#               year_release    0.061923
# votes         name            0.012615
#               rating          0.006031
#               genre          -0.135990
#               year            0.206021
#               released        0.028833
#               score           0.474256
#               votes           1.000000
#               director       -0.010376
#               writer         -0.005316
#               star           -0.017638
#               country         0.041551
#               budget          0.439675
#               gross           0.614751
#               company         0.118470
#               runtime         0.352303
#               year_release    0.203098
# director      name            0.015246
#               rating          0.014656
#               genre          -0.008553
#               year           -0.038354
#               released        0.002308
#               score           0.005413
#               votes          -0.010376
#               director        1.000000
#               writer          0.261735
#               star            0.036593
#               country         0.011133
#               budget         -0.009662
#               gross          -0.029560
#               company        -0.008223
#               runtime         0.017433
#               year_release   -0.037371
# writer        name            0.012880
#               rating         -0.003149
#               genre           0.017578
#               year           -0.025908
#               released        0.008072
#               score           0.012843
#               votes          -0.005316
#               director        0.261735
#               writer          1.000000
#               star            0.018520
#               country         0.022488
#               budget         -0.039466
#               gross          -0.035885
#               company        -0.003697
#               runtime        -0.017561
#               year_release   -0.025495
# star          name           -0.006882
#               rating          0.009196
#               genre           0.003341
#               year           -0.032157
#               released        0.015706
#               score           0.007296
#               votes          -0.017638
#               director        0.036593
#               writer          0.018520
#               star            1.000000
#               country        -0.009990
#               budget         -0.021473
#               gross          -0.000004
#               company         0.014082
#               runtime         0.010108
#               year_release   -0.032687
# country       name           -0.025490
#               rating          0.008230
#               genre          -0.009164
#               year           -0.066748
#               released       -0.017228
#               score          -0.043051
#               votes           0.041551
#               director        0.011133
#               writer          0.022488
#               star           -0.009990
#               country         1.000000
#               budget          0.052977
#               gross           0.060078
#               company         0.048569
#               runtime        -0.034477
#               year_release   -0.073569
# budget        name            0.023392
#               rating         -0.203946
#               genre          -0.368523
#               year            0.327722
#               released        0.019952
#               score           0.072001
#               votes           0.439675
#               director       -0.009662
#               writer         -0.039466
#               star           -0.021473
#               country         0.052977
#               budget          1.000000
#               gross           0.740247
#               company         0.170235
#               runtime         0.318695
#               year_release    0.320312
# gross         name            0.005639
#               rating         -0.181906
#               genre          -0.244101
#               year            0.274321
#               released        0.008501
#               score           0.222556
#               votes           0.614751
#               director       -0.029560
#               writer         -0.035885
#               star           -0.000004
#               country         0.060078
#               budget          0.740247
#               gross           1.000000
#               company         0.149553
#               runtime         0.275796
#               year_release    0.268721
# company       name            0.021697
#               rating         -0.092357
#               genre          -0.071334
#               year           -0.014333
#               released       -0.002407
#               score           0.020656
#               votes           0.118470
#               director       -0.008223
#               writer         -0.003697
#               star            0.014082
#               country         0.048569
#               budget          0.170235
#               gross           0.149553
#               company         1.000000
#               runtime         0.037585
#               year_release   -0.018806
# runtime       name            0.010850
#               rating          0.140792
#               genre          -0.059237
#               year            0.075077
#               released        0.008975
#               score           0.414068
#               votes           0.352303
#               director        0.017433
#               writer         -0.017561
#               star            0.010108
#               country        -0.034477
#               budget          0.318695
#               gross           0.275796
#               company         0.037585
#               runtime         1.000000
#               year_release    0.075294
# year_release  name            0.025542
#               rating          0.022021
#               genre          -0.069147
#               year            0.998726
#               released       -0.005989
#               score           0.061923
#               votes           0.203098
#               director       -0.037371
#               writer         -0.025495
#               star           -0.032687
#               country        -0.073569
#               budget          0.320312
#               gross           0.268721
#               company        -0.018806
#               runtime         0.075294
#               year_release    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre         budget         -0.368523
# budget        genre          -0.368523
# gross         genre          -0.244101
# genre         gross          -0.244101
# rating        budget         -0.203946
# budget        rating         -0.203946
# rating        gross          -0.181906
# gross         rating         -0.181906
# votes         genre          -0.135990
# genre         votes          -0.135990
# company       rating         -0.092357
# rating        company        -0.092357
# country       year_release   -0.073569
# year_release  country        -0.073569
# year          genre          -0.073167
# genre         year           -0.073167
#               company        -0.071334
# company       genre          -0.071334
# genre         year_release   -0.069147
# year_release  genre          -0.069147
# year          country        -0.066748
# country       year           -0.066748
# genre         runtime        -0.059237
# runtime       genre          -0.059237
# score         country        -0.043051
# country       score          -0.043051
# writer        budget         -0.039466
# budget        writer         -0.039466
# year          director       -0.038354
# director      year           -0.038354
#               year_release   -0.037371
# year_release  director       -0.037371
# gross         writer         -0.035885
# writer        gross          -0.035885
# runtime       country        -0.034477
# country       runtime        -0.034477
# star          year_release   -0.032687
# year_release  star           -0.032687
# star          year           -0.032157
# year          star           -0.032157
# director      gross          -0.029560
# gross         director       -0.029560
# name          rating         -0.029234
# rating        name           -0.029234
# year          writer         -0.025908
# writer        year           -0.025908
# year_release  writer         -0.025495
# writer        year_release   -0.025495
# country       name           -0.025490
# name          country        -0.025490
# budget        star           -0.021473
# star          budget         -0.021473
# year_release  company        -0.018806
# company       year_release   -0.018806
# star          votes          -0.017638
# votes         star           -0.017638
# runtime       writer         -0.017561
# writer        runtime        -0.017561
# country       released       -0.017228
# released      country        -0.017228
# company       year           -0.014333
# year          company        -0.014333
# director      votes          -0.010376
# votes         director       -0.010376
# star          country        -0.009990
# country       star           -0.009990
# budget        director       -0.009662
# director      budget         -0.009662
# country       genre          -0.009164
# genre         country        -0.009164
# director      genre          -0.008553
# genre         director       -0.008553
# director      company        -0.008223
# company       director       -0.008223
# name          star           -0.006882
# star          name           -0.006882
# name          released       -0.006152
# released      name           -0.006152
# year_release  released       -0.005989
# released      year_release   -0.005989
# votes         writer         -0.005316
# writer        votes          -0.005316
#               company        -0.003697
# company       writer         -0.003697
# rating        writer         -0.003149
# writer        rating         -0.003149
# company       released       -0.002407
# released      company        -0.002407
# year          released       -0.001740
# released      year           -0.001740
# gross         star           -0.000004
# star          gross          -0.000004
# director      released        0.002308
# released      director        0.002308
# genre         star            0.003341
# star          genre           0.003341
# director      score           0.005413
# score         director        0.005413
# gross         name            0.005639
# name          gross           0.005639
# votes         rating          0.006031
# rating        votes           0.006031
# score         star            0.007296
# star          score           0.007296
# writer        released        0.008072
# released      writer          0.008072
# country       rating          0.008230
# rating        country         0.008230
# gross         released        0.008501
# released      gross           0.008501
#               runtime         0.008975
# runtime       released        0.008975
# rating        star            0.009196
# star          rating          0.009196
#               runtime         0.010108
# runtime       star            0.010108
# name          runtime         0.010850
# runtime       name            0.010850
# genre         name            0.010996
# name          genre           0.010996
# country       director        0.011133
# director      country         0.011133
# name          votes           0.012615
# votes         name            0.012615
# score         writer          0.012843
# writer        score           0.012843
# name          writer          0.012880
# writer        name            0.012880
# star          company         0.014082
# company       star            0.014082
# name          score           0.014450
# score         name            0.014450
# director      rating          0.014656
# rating        director        0.014656
# director      name            0.015246
# name          director        0.015246
# released      star            0.015706
# star          released        0.015706
# runtime       director        0.017433
# director      runtime         0.017433
# writer        genre           0.017578
# genre         writer          0.017578
# rating        released        0.018083
# released      rating          0.018083
# writer        star            0.018520
# star          writer          0.018520
# year          rating          0.019499
# rating        year            0.019499
# budget        released        0.019952
# released      budget          0.019952
# company       score           0.020656
# score         company         0.020656
# company       name            0.021697
# name          company         0.021697
# rating        year_release    0.022021
# year_release  rating          0.022021
# genre         released        0.022142
# released      genre           0.022142
# writer        country         0.022488
# country       writer          0.022488
# name          budget          0.023392
# budget        name            0.023392
# name          year_release    0.025542
# year_release  name            0.025542
# name          year            0.025542
# year          name            0.025542
# released      votes           0.028833
# votes         released        0.028833
# score         genre           0.035106
# genre         score           0.035106
# star          director        0.036593
# director      star            0.036593
# runtime       company         0.037585
# company       runtime         0.037585
# votes         country         0.041551
# country       votes           0.041551
# score         released        0.045874
# released      score           0.045874
# country       company         0.048569
# company       country         0.048569
# budget        country         0.052977
# country       budget          0.052977
# year          score           0.056386
# score         year            0.056386
# gross         country         0.060078
# country       gross           0.060078
# score         year_release    0.061923
# year_release  score           0.061923
# rating        score           0.065983
# score         rating          0.065983
#               budget          0.072001
# budget        score           0.072001
# runtime       year            0.075077
# year          runtime         0.075077
# runtime       year_release    0.075294
# year_release  runtime         0.075294
# company       votes           0.118470
# votes         company         0.118470
# rating        runtime         0.140792
# runtime       rating          0.140792
# genre         rating          0.147796
# rating        genre           0.147796
# gross         company         0.149553
# company       gross           0.149553
# budget        company         0.170235
# company       budget          0.170235
# votes         year_release    0.203098
# year_release  votes           0.203098
# votes         year            0.206021
# year          votes           0.206021
# score         gross           0.222556
# gross         score           0.222556
# director      writer          0.261735
# writer        director        0.261735
# year_release  gross           0.268721
# gross         year_release    0.268721
# year          gross           0.274321
# gross         year            0.274321
#               runtime         0.275796
# runtime       gross           0.275796
# budget        runtime         0.318695
# runtime       budget          0.318695
# year_release  budget          0.320312
# budget        year_release    0.320312
#               year            0.327722
# year          budget          0.327722
# votes         runtime         0.352303
# runtime       votes           0.352303
# score         runtime         0.414068
# runtime       score           0.414068
# votes         budget          0.439675
# budget        votes           0.439675
# score         votes           0.474256
# votes         score           0.474256
# gross         votes           0.614751
# votes         gross           0.614751
# gross         budget          0.740247
# budget        gross           0.740247
# year          year_release    0.998726
# year_release  year            0.998726
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year_release  year_release    1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross         votes           0.614751
# votes         gross           0.614751
# gross         budget          0.740247
# budget        gross           0.740247
# year          year_release    0.998726
# year_release  year            0.998726
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# year_release  year_release    1.000000
# dtype: float64

# %%
 # Votes and budget have high correlation with gross
